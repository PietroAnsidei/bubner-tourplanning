# %%
import numpy as np
import pandas as pd
import requests
import pickle

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %% [markdown]
# # Get distance and time matrices using OSRM API

# %% [markdown]
# ## API

# %%
stops_df = pd.read_excel('../Data collection_v3.xlsx',sheet_name='Stops 2.Tour (Mo-Fr)')

# %%
stops_df
# Out:
#     No  Customer ID                    Stop name Duration (in min)  \
# 0    1         9012             Fiwa Nord (9012)          00:15:00
# 1    2         9005            Fiwa Markt (9005)          00:15:00
# 2    3         9002              Fiwa Süd (9002)          00:15:00
# 3    4         9003            Fiwa Edeka (9003)          00:15:00
# 4    5         9017                 Calau (9017)          00:15:00
# 5    6         9010              Lübbenau (9010)          00:15:00
# 6    7         9025               Cottbus (9025)          00:15:00
# 7    8         9018       Kirchhain Markt (9018)          00:15:00
# 8    9         9026       Kirchhain Edeke (9026)          00:15:00
# 9   10         9007        Herzberg Penny (9007)          00:15:00
# 10  11         9023      Herzberg Zentrum (9023)          00:15:00
# 11  12         9006                  Sowa (9006)          00:15:00
# 12  13         9019                Luckau (9019)          00:15:00
# 13  14         9024                Lübben (9024)          00:15:00
# 14  15         9011            Falkenberg (9011)          00:15:00
# 15  16         9014                  BaLi (9014)          00:15:00
# 16  17         9009           Elsterwerda (9009)          00:15:00
# 17  18         9022          Schwarzheide (9022)          00:15:00
# 18  19         9031      Senftenberg Rewe (9031)          00:15:00
# 19  20         9015           Großräschen (9015)          00:15:00
# 20  21         9008  Falkenberg Uebigauer (9008)          00:15:00
#
#     Dependency      Type Stop type                       Address  Postal Code  \
# 0          NaN  Delivery     Store           Kirchhainer Str. 12         3238
# 1          NaN  Delivery     Store                      Markt 28         3238
# 2          NaN  Delivery     Store      Rosa-Luxemburg-Straße 69         3238
# 3          NaN  Delivery     Store            Berliner Str. 20 b         3238
# 4          NaN  Delivery     Store             Cottbuser Str. 44         3205
# 5          NaN  Delivery     Store              Ehm-Welk-Str. 35         3222
# 6          NaN  Delivery     Store                 Rosenstraße 4         3046
# 7          NaN  Delivery     Store                    Am Markt 3         3253
# 8          NaN  Delivery     Store               Gerberstraße 22         3253
# 9          NaN  Delivery     Store            Grochwitzer Str. 2         4916
# 10         NaN  Delivery     Store                       Markt 5         4916
# 11         NaN  Delivery     Store                      Markt 35         3249
# 12         NaN  Delivery     Store                 Hauptstraße 3        15926
# 13         NaN  Delivery     Store                    Am Markt 6        15907
# 14         NaN  Delivery     Store                Lindenstraße 3         4895
# 15         NaN  Delivery     Store                   Roßmarkt 12         4924
# 16         NaN  Delivery     Store           Lauchhammer Str. 60         4910
# 17         NaN  Delivery     Store             Schipkauer Str. 3         1987
# 18         NaN  Delivery     Store              Bahnhofstraße 40         1968
# 19         NaN  Delivery     Store  Rudolf-Breitscheid-Straße 16         1983
# 20         NaN  Delivery     Store            Uebigauer Straße 1         4895
#
#                   Town  Opening   Time from  Time to  \
# 0         Finsterwalde       NaN        NaN      NaN
# 1         Finsterwalde       NaN        NaN      NaN
# 2         Finsterwalde       NaN        NaN      NaN
# 3         Finsterwalde       NaN        NaN      NaN
# 4                Calau       NaN        NaN      NaN
# 5   Lübbenau/Spreewald       NaN        NaN      NaN
# 6              Cottbus       NaN        NaN      NaN
# 7   Doberlug-Kirchhain       NaN        NaN      NaN
# 8   Doberlug-Kirchhain       NaN        NaN      NaN
# 9    Herzberg (Elster)       NaN        NaN      NaN
# 10   Herzberg (Elster)       NaN        NaN      NaN
# 11          Sonnewalde       NaN        NaN      NaN
# 12              Luckau       NaN        NaN      NaN
# 13  Lübben (Spreewald)       NaN        NaN      NaN
# 14  Falkenberg/ Elster       NaN        NaN      NaN
# 15     Bad Liebenwerda       NaN        NaN      NaN
# 16         Elsterwerda       NaN        NaN      NaN
# 17        Schwarzheide       NaN        NaN      NaN
# 18         Senftenberg       NaN        NaN      NaN
# 19         Großräschen       NaN        NaN      NaN
# 20  Falkenberg/ Elster       NaN        NaN      NaN
#
#                        Latitude, Longitude
# 0    51.63647133321395, 13.704593369766636
# 1   51.629624536601284, 13.708361310244655
# 2    51.62273511871606, 13.715053667916017
# 3   51.634787798008055, 13.706825712095014
# 4   51.746938845168074, 13.950017440934058
# 5   51.868367097476884, 13.968177200459339
# 6    51.75854401147092, 14.337405602306243
# 7    51.63745434921447, 13.562850371127455
# 8    51.63772004525862, 13.565081968065178
# 9    51.69132509071261, 13.226475610246515
# 10  51.692670038544875, 13.235057625589485
# 11  51.695714482922284, 13.646774398604009
# 12   51.85297305510116, 13.713940685115906
# 13   51.94173240024925, 13.895785640939774
# 14   51.58780069552828, 13.235616371615365
# 15   51.51596315711454, 13.394921112091476
# 16  51.465021495479824, 13.533434312090055
# 17  51.467827636403335, 13.870686656268836
# 18  51.559313325646336, 13.999790271460139
# 19   51.58804290089093, 14.012146598600864
# 20  51.588042199301995, 13.255818242407956

# %%
len(stops_df['Customer ID']) == len(stops_df['Customer ID'].unique())
# Out:
# True

# %%
no_to_customer_id_dict = {
    **{0: 'depot'},
    **pd.Series(stops_df['Customer ID'].values,index=stops_df['No']).to_dict()
}

# %%
no_to_customer_id_dict
# Out:
# {0: 'depot',
#  1: 9012,
#  2: 9005,
#  3: 9002,
#  4: 9003,
#  5: 9017,
#  6: 9010,
#  7: 9025,
#  8: 9018,
#  9: 9026,
#  10: 9007,
#  11: 9023,
#  12: 9006,
#  13: 9019,
#  14: 9024,
#  15: 9011,
#  16: 9014,
#  17: 9009,
#  18: 9022,
#  19: 9031,
#  20: 9015,
#  21: 9008}

# %%
base_url = 'http://router.project-osrm.org/table/v1/driving/'

# %%
# The format for OSRM is longitude/latitude, not latitude/longitude
long_lat_str = ';'.join(
    [
        ','.join(x.replace(' ','').split(',')[::-1]) for x in list(stops_df['Latitude, Longitude'])
    ])

# Add the coordinates of the production centre at Gewerbegebiet Südstraße 5
long_lat_str = '13.5853717,51.6286970;'+long_lat_str

# %%
long_lat_str
# Out:
# '13.5853717,51.6286970;13.704593369766636,51.63647133321395;13.708361310244655,51.629624536601284;13.715053667916017,51.62273511871606;13.706825712095014,51.634787798008055;13.950017440934058,51.746938845168074;13.968177200459339,51.868367097476884;14.337405602306243,51.75854401147092;13.562850371127455,51.63745434921447;13.565081968065178,51.63772004525862;13.226475610246515,51.69132509071261;13.235057625589485,51.692670038544875;13.646774398604009,51.695714482922284;13.713940685115906,51.85297305510116;13.895785640939774,51.94173240024925;13.235616371615365,51.58780069552828;13.394921112091476,51.51596315711454;13.533434312090055,51.465021495479824;13.870686656268836,51.467827636403335;13.999790271460139,51.559313325646336;14.012146598600864,51.58804290089093;13.255818242407956,51.588042199301995'

# %%
params = {'annotations': 'distance,duration'}

# %%
# https://project-osrm.org/docs/v5.22.0/api/#general-options
#response = (
    requests.get(base_url+long_lat_str,params=params)
)

# %%
#with open('osrm_response_20221121.pickle', 'wb') as handle:
    pickle.dump(response, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Unpickle

# %%
with open('osrm_response_20221121.pickle', 'rb') as handle:
    response = pickle.load(handle)

# %%
response.json()
# Out:
# {'code': 'Ok',
#  'distances': [[0,
#    9050.6,
#    10003.6,
#    11169.6,
#    9462.9,
#    36421,
#    54742.5,
#    85087.1,
#    2875.1,
#    2975.1,
#    31026.7,
#    30210.7,
#    10038,
#    31882.1,
#    48765.2,
#    29193.7,
#    23756.4,
#    36230.9,
#    42751.1,
#    34553.5,
#    33043.4,
#    27690.7],
#   [9051.4,
#    0,
#    953,
#    2010.6,
#    412.3,
#    27370.4,
#    45691.9,
#    76036.6,
#    11391,
#    11491.1,
#    39542.6,
#    38726.7,
#    9071.8,
#    30915.8,
#    47798.9,
#    37709.7,
#    32272.3,
#    28501.1,
#    33700.5,
#    25502.9,
#    23992.8,
#    36206.6],
#   [10198.9,
#    1215,
#    0,
#    1057.6,
#    935.2,
#    27215.9,
#    45537.3,
#    75882,
#    12538.5,
#    12638.6,
#    40690.1,
#    39874.2,
#    10065,
#    31909,
#    48792.1,
#    38611.7,
#    33174.3,
#    27022,
#    33546,
#    25348.4,
#    23838.3,
#    37108.7],
#   [11174.5,
#    1959.5,
#    1073.6,
#    0,
#    1723.1,
#    27933,
#    46254.5,
#    76599.2,
#    14810.3,
#    14910.4,
#    42961.9,
#    42146,
#    10809.4,
#    32653.5,
#    59430.2,
#    39514.4,
#    36736.3,
#    25964.5,
#    34263.1,
#    26065.5,
#    24555.5,
#    38011.4],
#   [9331.9,
#    508.3,
#    682.3,
#    1739.9,
#    0,
#    27268.8,
#    45590.3,
#    75935,
#    11671.4,
#    11771.5,
#    39823,
#    39007.1,
#    9358.2,
#    31202.3,
#    48085.4,
#    37990.1,
#    32552.7,
#    27704.3,
#    33598.9,
#    25401.3,
#    23891.3,
#    36487],
#   [36353.4,
#    27301.9,
#    27267,
#    27878.9,
#    27186.2,
#    0,
#    15033.9,
#    34201.3,
#    37097.9,
#    36944.2,
#    62935.1,
#    62119.1,
#    27016.9,
#    21013,
#    33188,
#    65011.6,
#    72080.6,
#    59266.2,
#    35492.8,
#    27923,
#    21083.4,
#    63508.5],
#   [54789.6,
#    45738.1,
#    45703.2,
#    46315.1,
#    45622.4,
#    15269.1,
#    0,
#    37141.9,
#    47281.5,
#    47127.9,
#    65224.6,
#    64408.7,
#    37200.6,
#    20140,
#    12951.5,
#    75533.2,
#    89536.6,
#    76722.2,
#    52948.8,
#    45378.9,
#    43868.8,
#    74030.1],
#   [86308.7,
#    77257.3,
#    77222.4,
#    77834.3,
#    77141.6,
#    33985.4,
#    36568.5,
#    0,
#    78800.7,
#    78647.1,
#    97450.4,
#    96634.5,
#    68719.8,
#    53063.1,
#    54284.7,
#    107759,
#    88622.9,
#    75808.5,
#    52045.9,
#    40829,
#    35492.2,
#    106255.9],
#   [3013.1,
#    11528.2,
#    12481.2,
#    14484.8,
#    11940.5,
#    37121.1,
#    47418.7,
#    77763.4,
#    0,
#    250.3,
#    28037.8,
#    27221.8,
#    10050.9,
#    31895,
#    48778,
#    29482,
#    23813,
#    36287.5,
#    45228.7,
#    37031.1,
#    35521,
#    27978.9],
#   [3003.2,
#    11518.2,
#    12471.2,
#    14474.9,
#    11930.6,
#    36966,
#    47263.6,
#    77608.3,
#    248.9,
#    0,
#    28267.1,
#    27451.2,
#    9895.8,
#    31739.9,
#    48622.9,
#    29711.3,
#    23803,
#    36277.6,
#    45218.8,
#    37021.2,
#    35511.1,
#    28208.3],
#   [30946.8,
#    39461.9,
#    40414.9,
#    42418.6,
#    39874.2,
#    63065.6,
#    65560.1,
#    97608,
#    28144.4,
#    28187.3,
#    0,
#    1003.3,
#    34537.1,
#    42204,
#    59087,
#    12228.5,
#    25806.3,
#    38323.1,
#    62036.8,
#    68502.3,
#    66992.2,
#    13618.9],
#   [30130.9,
#    38646,
#    39599,
#    41602.7,
#    39058.3,
#    62249.7,
#    64744.2,
#    96792.1,
#    27328.5,
#    27371.4,
#    1003.3,
#    0,
#    33721.1,
#    41388,
#    58271.1,
#    12581.2,
#    24990.3,
#    37507.2,
#    61220.8,
#    67686.4,
#    66176.3,
#    13971.6],
#   [10038,
#    9071.8,
#    9803,
#    10860.5,
#    9262.3,
#    27070.2,
#    37367.8,
#    67712.5,
#    10080.9,
#    9927.3,
#    34589.5,
#    33773.5,
#    0,
#    21844.1,
#    38727.1,
#    41629,
#    33486.7,
#    37461.3,
#    42162.9,
#    33965.3,
#    32455.2,
#    40125.9],
#   [31683.9,
#    30717.7,
#    31448.9,
#    32506.4,
#    30908.2,
#    21231.5,
#    20162,
#    52802.8,
#    31726.8,
#    31573.2,
#    42008.2,
#    41192.3,
#    21645.9,
#    0,
#    17619.9,
#    52316.8,
#    55161,
#    77606.3,
#    53832.9,
#    46263.1,
#    44753,
#    50813.7],
#   [48713.7,
#    47747.4,
#    48478.6,
#    59399.7,
#    47937.9,
#    33889.5,
#    12938,
#    55300,
#    48756.6,
#    48602.9,
#    59038,
#    58222,
#    38675.7,
#    17691.8,
#    0,
#    69346.6,
#    72190.8,
#    89806.7,
#    66033.3,
#    58463.5,
#    56953.4,
#    67843.5],
#   [29193.7,
#    37708.8,
#    38521.7,
#    39037.4,
#    38121.1,
#    65079.2,
#    75871.1,
#    107919,
#    29641,
#    29683.9,
#    12228.5,
#    12581.2,
#    41629,
#    52515,
#    69398,
#    0,
#    16583,
#    30030.7,
#    53744.4,
#    72464.4,
#    73206.3,
#    1503.1],
#   [23765,
#    32280.1,
#    33093,
#    38648.3,
#    32692.4,
#    73714,
#    91450.1,
#    90504.1,
#    23700.3,
#    23800.4,
#    25883.7,
#    25067.8,
#    33480.6,
#    55384.3,
#    72267.3,
#    16404.5,
#    0,
#    15727.9,
#    39441.6,
#    58161.6,
#    58903.6,
#    17398.4],
#   [36092.8,
#    28363.2,
#    26900.2,
#    25826.6,
#    27549.7,
#    58888,
#    76624.1,
#    75678.2,
#    36028.1,
#    36128.2,
#    38228.3,
#    37412.4,
#    36636,
#    78063.6,
#    89799.8,
#    29856.8,
#    13716.4,
#    0,
#    24615.6,
#    43335.7,
#    44077.6,
#    30850.7],
#   [43864.7,
#    34813.2,
#    34778.4,
#    35390.2,
#    34697.6,
#    35905.4,
#    53641.5,
#    52053.7,
#    46204.2,
#    46304.3,
#    62080.1,
#    61264.2,
#    43278.3,
#    55081,
#    66817.2,
#    53708.6,
#    37568.2,
#    24753.8,
#    0,
#    20353,
#    21094.9,
#    54702.5],
#   [34539.1,
#    25487.7,
#    25452.8,
#    26064.7,
#    25372,
#    26966.4,
#    44702.5,
#    40837.1,
#    36878.6,
#    36978.7,
#    68542.2,
#    67726.3,
#    33952.7,
#    46142,
#    57878.2,
#    72547.5,
#    56407.1,
#    43592.7,
#    19819.3,
#    0,
#    6645.6,
#    73541.4],
#   [33029.2,
#    23977.8,
#    23942.9,
#    24554.8,
#    23862.1,
#    21127.1,
#    43192.6,
#    35500.1,
#    35368.7,
#    35468.8,
#    67032.3,
#    66216.4,
#    32442.8,
#    44632.1,
#    56368.3,
#    73289.4,
#    57148.9,
#    44334.5,
#    20561.1,
#    6645.5,
#    0,
#    74283.3],
#   [27690.7,
#    36205.7,
#    37018.7,
#    37534.4,
#    36618.1,
#    63576.2,
#    74368,
#    106415.9,
#    28137.9,
#    28180.9,
#    13618.9,
#    13971.6,
#    40125.9,
#    51011.9,
#    67895,
#    1503.1,
#    17541.1,
#    30988.8,
#    54702.5,
#    73422.5,
#    74164.5,
#    0]],
#  'destinations': [{'hint': 'gBlOgfOCcI0SAAAAPAAAAHsAAABnAAAA0ZFxQFmSSEE5h85B-uKsQQkAAAAeAAAAPgAAADMAAAC78gAArUzPAP3KEwPcS88AmcoTAwUA7wgTAObo',
#    'distance': 18.255987,
#    'name': '',
#    'location': [13.585581, 51.628797]},
#   {'hint': 'STV6gCPzf4YTAAAAEwAAAAAAAAAAAAAA-2eqQQbeqEEAAAAAAAAAABMAAAATAAAAAAAAAAAAAAC78gAANB7RAP_nEwORHdEA9-gTAwAAPwQTAObo',
#    'distance': 29.812391,
#    'name': 'Kirchhainer Straße',
#    'location': [13.704756, 51.636223]},
#   {'hint': '4FJ-gP___38FAAAARAAAAAAAAAAKAAAApyJwQCMYJ0IAAAAA29HWQAUAAABEAAAAAAAAAAoAAAC78gAASyzRADLOEwNJLNEAOc4TAwAA3wQTAObo',
#    'distance': 0.791045,
#    'name': 'Markt',
#    'location': [13.708363, 51.629618]},
#   {'hint': 'wVJ-gPo4eoICAAAAQAAAAAAAAAAAAAAAYMEwQNevjEIAAAAAAAAAAAIAAABAAAAAAAAAAAAAAAC78gAAYUbRAFKzEwNuRtEAT7MTAwAArwwTAObo',
#    'distance': 0.960169,
#    'name': 'Rosa-Luxemburg-Straße',
#    'location': [13.715041, 51.622738]},
#   {'hint': 'JgEMirRa2YpNAAAAMQAAAAAAAAAVAAAAExqCQeq4IUEAAAAAmjuKQCYAAAAZAAAAAAAAAAoAAAC78gAAhybRAP_iEwNKJtEAZOITAwAAvxETAObo',
#    'distance': 17.755284,
#    'name': '',
#    'location': [13.706887, 51.634943]},
#   {'hint': 'flaEhBAlMpESAAAABwAAAFoAAAD3AAAAQz-fQDg87z_fXchB4gCJQhIAAAAHAAAAWgAAAPcAAAC78gAAPdzUAC6YFQNB3NQAe5gVAwIAvwUTAObo',
#    'distance': 8.571684,
#    'name': 'Cottbuser Straße',
#    'location': [13.950013, 51.746862]},
#   {'hint': '2Oieg2xmlYYCAAAACgAAAB8AAADSAAAAFOuwP2BezkBpAqpB2tcMQwIAAAAKAAAAHwAAANIAAAC78gAAPCPVAOZyFwMxI9UAz3IXAwIA7xETAObo',
#    'distance': 2.668889,
#    'name': 'Ehm-Welk-Straße',
#    'location': [13.968188, 51.86839]},
#   {'hint': 'Rh1zjYUec40qAAAABAAAAAAAAAAAAAAAXyHjQUsWGEAAAAAAAAAAACoAAAAEAAAAAAAAAAAAAAC78gAA18XaAA_GFQN-xdoA0MUVAwAALwgTAObo',
#    'distance': 9.320563,
#    'name': 'Breite Straße',
#    'location': [14.337495, 51.758607]},
#   {'hint': 'Thuoif___38fAAAANgAAAAAAAAAAAAAAh94NQqf7xUEAAAAAAAAAAB8AAAA2AAAAAAAAAAAAAAC78gAAmvPOAE_sEwPi884AzuwTAwAAHxITAObo',
#    'distance': 14.984069,
#    'name': 'Gerichtsstraße',
#    'location': [13.562778, 51.637327]},
#   {'hint': 'NQ2miTgNpok3AAAAIAAAAAAAAADZAAAAALI6QWjM0EAAAAAAk5k0QhwAAAAQAAAAAAAAAGwAAAC78gAAovzOAJftEwOa_M4A2O0TAwAAXwUTAObo',
#    'distance': 7.253139,
#    'name': '',
#    'location': [13.56509, 51.637655]},
#   {'hint': 'vjQDhcA0A4UOAAAAOgAAAPUAAAAAAAAA8b4_QB59QEHDZ0xCAAAAAAcAAAAdAAAAewAAAAAAAAC78gAABdLJAEu_FAPs0ckAPb8UAwIA3xMTAObo',
#    'distance': 2.327486,
#    'name': '',
#    'location': [13.226501, 51.691339]},
#   {'hint': 'YN7dgN1C3oAyAAAACgAAABkAAABzAAAABhsIQsuAwUDexINBgr-ZQjIAAAAKAAAAGQAAAHMAAAC78gAAcvTJANLEFANy88kAfsQUAwIAzxQTAObo',
#    'distance': 20.024072,
#    'name': 'Mönchstraße',
#    'location': [13.235314, 51.692754]},
#   {'hint': 'NdlMget_cI0WAAAABwAAAAAAAAAAAAAAEjEjQprpP0EAAAAAAAAAABYAAAAHAAAAAAAAAAAAAAC78gAAqTvQAHTQFAO2O9AAYtAUAwAAbw8TAObo',
#    'distance': 2.195355,
#    'name': 'Markt',
#    'location': [13.646761, 51.695732]},
#   {'hint': '9xZ-gVcZfoEIAAAADAAAACEAAAAyAAAA0a21QJWKBUFXdrdBX9QKQggAAAAMAAAAIQAAADIAAAC78gAAG0PRANw2FwMVQtEArTYXAwEAfxUTAObo',
#    'distance': 18.786837,
#    'name': 'Kirchstraße',
#    'location': [13.714203, 51.85302]},
#   {'hint': 'NVl4gFFZeIAoAAAARQAAAAgAAAAIAAAAOofWQWftNkLFBrJA1XquQCgAAABFAAAACAAAAAgAAAC78gAAKQnUAGWRGANqCNQAZJEYAwEAfxYTAObo',
#    'distance': 13.14033,
#    'name': 'Am Markt',
#    'location': [13.895977, 51.941733]},
#   {'hint': 'MNmfgl7Zn4LHAAAAZwAAAAAAAABdAAAAVRAmQk4Hq0EAAAAA2a-aQWMAAAA0AAAAAAAAAC4AAAC78gAA7PXJAOAqEwOg9ckA2SoTAwAA_xUTAObo',
#    'distance': 5.326239,
#    'name': '',
#    'location': [13.235692, 51.587808]},
#   {'hint': 'mj7OjMZCzow_AAAAAAAAAAAAAAAAAAAAbT5RQQAAAAAAAAAAAAAAAB8AAAAAAAAAAAAAAAAAAAC78gAA-mTMAHASEgPpY8wAOxISAwAAbxITAObo',
#    'distance': 19.843893,
#    'name': '',
#    'location': [13.395194, 51.516016]},
#   {'hint': 'ZKfWgRunMYZaAAAAIgAAAAAAAAAAAAAAWFUhQZ6Ta0AAAAAAAAAAAC0AAAARAAAAAAAAAAAAAAC78gAADIDOAHVMEQP6gM4APUsRAwAADwQTAObo',
#    'distance': 38.450076,
#    'name': '',
#    'location': [13.533196, 51.465333]},
#   {'hint': 'F-uQhS7rkIVNAAAAAAAAAAAAAADOAAAA-sWAQQAAAAAAAAAAmHorQicAAAAAAAAAAAAAAGcAAAC78gAAwaXTAGVWEQNfptMANFYRAwAA7wUTAObo',
#    'distance': 12.257089,
#    'name': '',
#    'location': [13.870529, 51.467877]},
#   {'hint': 'fVaSgaq9rYQAAAAAHwAAAIAUAABUAAAAAAAAAGTuCkHjnLZEyK-7QQAAAAAfAAAAgBQAAFQAAAC78gAAH6TVABi6EgOuntUAkbsSAxcAjwETAObo',
#    'distance': 105.290642,
#    'name': '',
#    'location': [14.001183, 51.558936]},
#   {'hint': '3dPcieDT3IkAAAAABwEAAAAAAAAAAAAAAAAAAFeYW0IAAAAAAAAAAAAAAACEAAAAAAAAAAAAAAC78gAApM_VAIIsEwPzztUAyysTAwAALwATAObo',
#    'distance': 23.772549,
#    'name': '',
#    'location': [14.012324, 51.588226]},
#   {'hint': '801zgIY-jIBpAAAAPAAAAAAAAAAAAAAA2H3rQqYIhEIAAAAAAAAAAGkAAAA8AAAAAAAAAAAAAAC78gAAlkTKAGYqEwOKRMoAyisTAwAAzxATAObo',
#    'distance': 39.617222,
#    'name': 'Uebigauer Straße',
#    'location': [13.25583, 51.587686]}],
#  'durations': [[0,
#    638.3,
#    777.6,
#    855.9,
#    702.5,
#    2483,
#    3120.2,
#    4134.3,
#    282.7,
#    303.4,
#    2237.8,
#    2137.6,
#    658.7,
#    1973.3,
#    2805.3,
#    2251.2,
#    1815.6,
#    2567.3,
#    2450.5,
#    2699.5,
#    2306.4,
#    2099.2],
#   [624.4,
#    0,
#    139.3,
#    282.2,
#    64.2,
#    1844.7,
#    2481.9,
#    3496,
#    830.5,
#    851.2,
#    2785.6,
#    2685.4,
#    629.4,
#    1944,
#    2776,
#    2799,
#    2363.4,
#    2055.2,
#    1812.2,
#    2061.2,
#    1668.1,
#    2647],
#   [791.2,
#    177.8,
#    0,
#    142.9,
#    167,
#    1871.3,
#    2508.5,
#    3522.6,
#    997.3,
#    1018,
#    2952.4,
#    2852.2,
#    776.1,
#    2090.7,
#    2922.7,
#    2853,
#    2417.4,
#    1951.6,
#    1838.8,
#    2087.8,
#    1694.7,
#    2701],
#   [852.8,
#    275.5,
#    153.3,
#    0,
#    273.5,
#    1820.7,
#    2457.9,
#    3472,
#    1037.9,
#    1058.6,
#    2993,
#    2892.8,
#    873.8,
#    2188.4,
#    2922.4,
#    2884.7,
#    2380.2,
#    1808.7,
#    1788.2,
#    2037.2,
#    1644.1,
#    2732.7],
#   [699.5,
#    88.3,
#    127.1,
#    270,
#    0,
#    1863.7,
#    2500.9,
#    3515,
#    905.6,
#    926.3,
#    2860.7,
#    2760.5,
#    686.6,
#    2001.2,
#    2833.2,
#    2874.1,
#    2438.5,
#    2078.7,
#    1831.2,
#    2080.2,
#    1687.1,
#    2722.1],
#   [2448.8,
#    1824.4,
#    1876.3,
#    1803.2,
#    1831.6,
#    0,
#    1151,
#    1854.5,
#    2643.3,
#    2639.5,
#    3903.7,
#    3803.5,
#    1935.6,
#    1387.7,
#    1791.5,
#    4623.4,
#    3910.4,
#    3121.7,
#    1757.9,
#    2083.6,
#    1561.6,
#    4471.4],
#   [3127.3,
#    2502.9,
#    2554.8,
#    2481.7,
#    2510.1,
#    1187.9,
#    0,
#    1888.2,
#    3052.8,
#    3049,
#    3721.6,
#    3621.4,
#    2345.1,
#    1404.7,
#    1091,
#    4491.8,
#    4490.7,
#    3702,
#    2338.2,
#    2663.9,
#    2270.8,
#    4339.8],
#   [4221,
#    3596.6,
#    3648.5,
#    3575.4,
#    3603.8,
#    1896,
#    1863.2,
#    0,
#    4146.5,
#    4142.7,
#    4838,
#    4737.8,
#    3438.8,
#    2556.6,
#    2496.7,
#    5608.2,
#    5443.5,
#    4654.8,
#    3219,
#    3254.5,
#    2357,
#    5456.2],
#   [294.6,
#    850,
#    989.3,
#    1056.4,
#    914.2,
#    2657.1,
#    3043.8,
#    4057.9,
#    0,
#    41.5,
#    1973.3,
#    1873.1,
#    704.2,
#    2018.8,
#    2850.8,
#    2242.3,
#    1832.8,
#    2584.5,
#    2662.2,
#    2911.2,
#    2518.1,
#    2090.3],
#   [301.6,
#    857,
#    996.3,
#    1063.4,
#    921.2,
#    2650.4,
#    3037.1,
#    4051.2,
#    45.2,
#    0,
#    1987.1,
#    1886.9,
#    697.5,
#    2012.1,
#    2844.1,
#    2256.1,
#    1839.8,
#    2591.5,
#    2669.2,
#    2918.2,
#    2525.1,
#    2104.1],
#   [2230.6,
#    2786,
#    2925.3,
#    2992.4,
#    2850.2,
#    3912.7,
#    3716.2,
#    4774.5,
#    1972.6,
#    1984.2,
#    0,
#    128.9,
#    2266.1,
#    2577.9,
#    3409.9,
#    912.3,
#    1735.3,
#    2495.9,
#    3742,
#    4798.5,
#    4405.4,
#    1033.4],
#   [2138.2,
#    2693.6,
#    2832.9,
#    2900,
#    2757.8,
#    3820.3,
#    3623.8,
#    4682.1,
#    1880.2,
#    1891.8,
#    142.1,
#    0,
#    2173.7,
#    2485.5,
#    3317.5,
#    952.6,
#    1642.9,
#    2403.5,
#    3649.6,
#    4706.1,
#    4313,
#    1073.7],
#   [644.2,
#    627.1,
#    739.5,
#    882.4,
#    664.4,
#    1952.9,
#    2339.6,
#    3353.7,
#    707.7,
#    703.9,
#    2271.8,
#    2171.6,
#    0,
#    1314.6,
#    2146.6,
#    2707.3,
#    2488.5,
#    2677.6,
#    2283.4,
#    2532.4,
#    2139.3,
#    2555.3],
#   [1941.8,
#    1924.7,
#    2037.1,
#    2180,
#    1962,
#    1419.4,
#    1403,
#    2493.4,
#    2005.3,
#    2001.5,
#    2576.7,
#    2476.5,
#    1297.6,
#    0,
#    1179.3,
#    3346.9,
#    3456,
#    3755.1,
#    2391.3,
#    2717,
#    2323.9,
#    3194.9],
#   [2779.3,
#    2762.2,
#    2874.6,
#    2882.2,
#    2799.5,
#    1823.4,
#    1092.2,
#    2503.2,
#    2842.8,
#    2839,
#    3414.2,
#    3314,
#    2135.1,
#    1187.4,
#    0,
#    4184.4,
#    4293.5,
#    4102.5,
#    2738.7,
#    3064.4,
#    2671.3,
#    4032.4],
#   [2247.7,
#    2803.1,
#    2826.8,
#    2884,
#    2867.3,
#    4647.8,
#    4495.8,
#    5554.1,
#    2250,
#    2261.6,
#    915.4,
#    952.5,
#    2712.2,
#    3357.5,
#    4189.5,
#    0,
#    1142,
#    1978.3,
#    3224.4,
#    4557.6,
#    4218.2,
#    151.9],
#   [1843.3,
#    2398.7,
#    2422.4,
#    2433.5,
#    2462.9,
#    3932.5,
#    4511.2,
#    5492.8,
#    1857.7,
#    1878.4,
#    1786.4,
#    1686.2,
#    2523.2,
#    3498,
#    4330,
#    1121.4,
#    0,
#    1178.1,
#    2424.2,
#    3757.4,
#    3418,
#    1185.9],
#   [2525.9,
#    2017.9,
#    1924.4,
#    1771.1,
#    2044.6,
#    3056.3,
#    3635,
#    4616.6,
#    2540.3,
#    2561,
#    2462.9,
#    2362.7,
#    2644.9,
#    3742.9,
#    4099.5,
#    1939.1,
#    1096.9,
#    0,
#    1548,
#    2881.2,
#    2541.8,
#    2003.6],
#   [2418.6,
#    1794.2,
#    1846.1,
#    1773,
#    1801.4,
#    1700,
#    2278.7,
#    3227.1,
#    2624.7,
#    2645.4,
#    3742.4,
#    3642.2,
#    2261.1,
#    2386.6,
#    2743.2,
#    3218.6,
#    2376.4,
#    1587.7,
#    0,
#    1524.9,
#    1185.5,
#    3283.1],
#   [2691.9,
#    2067.5,
#    2119.4,
#    2046.3,
#    2074.7,
#    2022.7,
#    2601.4,
#    3252.4,
#    2898,
#    2918.7,
#    4806.2,
#    4706,
#    2534.4,
#    2709.3,
#    3065.9,
#    4580.7,
#    3738.5,
#    2949.8,
#    1586,
#    0,
#    1054.7,
#    4645.2],
#   [2295.9,
#    1671.5,
#    1723.4,
#    1650.3,
#    1678.7,
#    1569.6,
#    2205.4,
#    2366,
#    2502,
#    2522.7,
#    4410.2,
#    4310,
#    2138.4,
#    2313.3,
#    2669.9,
#    4241.7,
#    3399.5,
#    2610.8,
#    1247,
#    1061.7,
#    0,
#    4306.2],
#   [2095.8,
#    2651.2,
#    2674.9,
#    2732.1,
#    2715.4,
#    4495.9,
#    4343.9,
#    5402.2,
#    2098.1,
#    2109.7,
#    1030,
#    1067.1,
#    2560.3,
#    3205.6,
#    4037.6,
#    152,
#    1214.9,
#    2051.2,
#    3297.3,
#    4630.5,
#    4291.1,
#    0]],
#  'sources': [{'hint': 'gBlOgfOCcI0SAAAAPAAAAHsAAABnAAAA0ZFxQFmSSEE5h85B-uKsQQkAAAAeAAAAPgAAADMAAAC78gAArUzPAP3KEwPcS88AmcoTAwUA7wgTAObo',
#    'distance': 18.255987,
#    'name': '',
#    'location': [13.585581, 51.628797]},
#   {'hint': 'STV6gCPzf4YTAAAAEwAAAAAAAAAAAAAA-2eqQQbeqEEAAAAAAAAAABMAAAATAAAAAAAAAAAAAAC78gAANB7RAP_nEwORHdEA9-gTAwAAPwQTAObo',
#    'distance': 29.812391,
#    'name': 'Kirchhainer Straße',
#    'location': [13.704756, 51.636223]},
#   {'hint': '4FJ-gP___38FAAAARAAAAAAAAAAKAAAApyJwQCMYJ0IAAAAA29HWQAUAAABEAAAAAAAAAAoAAAC78gAASyzRADLOEwNJLNEAOc4TAwAA3wQTAObo',
#    'distance': 0.791045,
#    'name': 'Markt',
#    'location': [13.708363, 51.629618]},
#   {'hint': 'wVJ-gPo4eoICAAAAQAAAAAAAAAAAAAAAYMEwQNevjEIAAAAAAAAAAAIAAABAAAAAAAAAAAAAAAC78gAAYUbRAFKzEwNuRtEAT7MTAwAArwwTAObo',
#    'distance': 0.960169,
#    'name': 'Rosa-Luxemburg-Straße',
#    'location': [13.715041, 51.622738]},
#   {'hint': 'JgEMirRa2YpNAAAAMQAAAAAAAAAVAAAAExqCQeq4IUEAAAAAmjuKQCYAAAAZAAAAAAAAAAoAAAC78gAAhybRAP_iEwNKJtEAZOITAwAAvxETAObo',
#    'distance': 17.755284,
#    'name': '',
#    'location': [13.706887, 51.634943]},
#   {'hint': 'flaEhBAlMpESAAAABwAAAFoAAAD3AAAAQz-fQDg87z_fXchB4gCJQhIAAAAHAAAAWgAAAPcAAAC78gAAPdzUAC6YFQNB3NQAe5gVAwIAvwUTAObo',
#    'distance': 8.571684,
#    'name': 'Cottbuser Straße',
#    'location': [13.950013, 51.746862]},
#   {'hint': '2Oieg2xmlYYCAAAACgAAAB8AAADSAAAAFOuwP2BezkBpAqpB2tcMQwIAAAAKAAAAHwAAANIAAAC78gAAPCPVAOZyFwMxI9UAz3IXAwIA7xETAObo',
#    'distance': 2.668889,
#    'name': 'Ehm-Welk-Straße',
#    'location': [13.968188, 51.86839]},
#   {'hint': 'Rh1zjYUec40qAAAABAAAAAAAAAAAAAAAXyHjQUsWGEAAAAAAAAAAACoAAAAEAAAAAAAAAAAAAAC78gAA18XaAA_GFQN-xdoA0MUVAwAALwgTAObo',
#    'distance': 9.320563,
#    'name': 'Breite Straße',
#    'location': [14.337495, 51.758607]},
#   {'hint': 'Thuoif___38fAAAANgAAAAAAAAAAAAAAh94NQqf7xUEAAAAAAAAAAB8AAAA2AAAAAAAAAAAAAAC78gAAmvPOAE_sEwPi884AzuwTAwAAHxITAObo',
#    'distance': 14.984069,
#    'name': 'Gerichtsstraße',
#    'location': [13.562778, 51.637327]},
#   {'hint': 'NQ2miTgNpok3AAAAIAAAAAAAAADZAAAAALI6QWjM0EAAAAAAk5k0QhwAAAAQAAAAAAAAAGwAAAC78gAAovzOAJftEwOa_M4A2O0TAwAAXwUTAObo',
#    'distance': 7.253139,
#    'name': '',
#    'location': [13.56509, 51.637655]},
#   {'hint': 'vjQDhcA0A4UOAAAAOgAAAPUAAAAAAAAA8b4_QB59QEHDZ0xCAAAAAAcAAAAdAAAAewAAAAAAAAC78gAABdLJAEu_FAPs0ckAPb8UAwIA3xMTAObo',
#    'distance': 2.327486,
#    'name': '',
#    'location': [13.226501, 51.691339]},
#   {'hint': 'YN7dgN1C3oAyAAAACgAAABkAAABzAAAABhsIQsuAwUDexINBgr-ZQjIAAAAKAAAAGQAAAHMAAAC78gAAcvTJANLEFANy88kAfsQUAwIAzxQTAObo',
#    'distance': 20.024072,
#    'name': 'Mönchstraße',
#    'location': [13.235314, 51.692754]},
#   {'hint': 'NdlMget_cI0WAAAABwAAAAAAAAAAAAAAEjEjQprpP0EAAAAAAAAAABYAAAAHAAAAAAAAAAAAAAC78gAAqTvQAHTQFAO2O9AAYtAUAwAAbw8TAObo',
#    'distance': 2.195355,
#    'name': 'Markt',
#    'location': [13.646761, 51.695732]},
#   {'hint': '9xZ-gVcZfoEIAAAADAAAACEAAAAyAAAA0a21QJWKBUFXdrdBX9QKQggAAAAMAAAAIQAAADIAAAC78gAAG0PRANw2FwMVQtEArTYXAwEAfxUTAObo',
#    'distance': 18.786837,
#    'name': 'Kirchstraße',
#    'location': [13.714203, 51.85302]},
#   {'hint': 'NVl4gFFZeIAoAAAARQAAAAgAAAAIAAAAOofWQWftNkLFBrJA1XquQCgAAABFAAAACAAAAAgAAAC78gAAKQnUAGWRGANqCNQAZJEYAwEAfxYTAObo',
#    'distance': 13.14033,
#    'name': 'Am Markt',
#    'location': [13.895977, 51.941733]},
#   {'hint': 'MNmfgl7Zn4LHAAAAZwAAAAAAAABdAAAAVRAmQk4Hq0EAAAAA2a-aQWMAAAA0AAAAAAAAAC4AAAC78gAA7PXJAOAqEwOg9ckA2SoTAwAA_xUTAObo',
#    'distance': 5.326239,
#    'name': '',
#    'location': [13.235692, 51.587808]},
#   {'hint': 'mj7OjMZCzow_AAAAAAAAAAAAAAAAAAAAbT5RQQAAAAAAAAAAAAAAAB8AAAAAAAAAAAAAAAAAAAC78gAA-mTMAHASEgPpY8wAOxISAwAAbxITAObo',
#    'distance': 19.843893,
#    'name': '',
#    'location': [13.395194, 51.516016]},
#   {'hint': 'ZKfWgRunMYZaAAAAIgAAAAAAAAAAAAAAWFUhQZ6Ta0AAAAAAAAAAAC0AAAARAAAAAAAAAAAAAAC78gAADIDOAHVMEQP6gM4APUsRAwAADwQTAObo',
#    'distance': 38.450076,
#    'name': '',
#    'location': [13.533196, 51.465333]},
#   {'hint': 'F-uQhS7rkIVNAAAAAAAAAAAAAADOAAAA-sWAQQAAAAAAAAAAmHorQicAAAAAAAAAAAAAAGcAAAC78gAAwaXTAGVWEQNfptMANFYRAwAA7wUTAObo',
#    'distance': 12.257089,
#    'name': '',
#    'location': [13.870529, 51.467877]},
#   {'hint': 'fVaSgaq9rYQAAAAAHwAAAIAUAABUAAAAAAAAAGTuCkHjnLZEyK-7QQAAAAAfAAAAgBQAAFQAAAC78gAAH6TVABi6EgOuntUAkbsSAxcAjwETAObo',
#    'distance': 105.290642,
#    'name': '',
#    'location': [14.001183, 51.558936]},
#   {'hint': '3dPcieDT3IkAAAAABwEAAAAAAAAAAAAAAAAAAFeYW0IAAAAAAAAAAAAAAACEAAAAAAAAAAAAAAC78gAApM_VAIIsEwPzztUAyysTAwAALwATAObo',
#    'distance': 23.772549,
#    'name': '',
#    'location': [14.012324, 51.588226]},
#   {'hint': '801zgIY-jIBpAAAAPAAAAAAAAAAAAAAA2H3rQqYIhEIAAAAAAAAAAGkAAAA8AAAAAAAAAAAAAAC78gAAlkTKAGYqEwOKRMoAyisTAwAAzxATAObo',
#    'distance': 39.617222,
#    'name': 'Uebigauer Straße',
#    'location': [13.25583, 51.587686]}]}

# %%
# Distance and time matrices
distances = response.json()['distances']
durations = response.json()['durations']

# %% [markdown]
# # Optimise on distances using OR-Tools

# %%
def create_data_model(num_vehicles):
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = distances
    data['num_vehicles'] = num_vehicles
    data['depot'] = 0
    return data

# %%
def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    print(f'Objective: {solution.ObjectiveValue()}')
    max_route_distance = 0
    sum_distances = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        while not routing.IsEnd(index):
            plan_output += f' {manager.IndexToNode(index)} ({no_to_customer_id_dict[manager.IndexToNode(index)]}) -> '
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
        plan_output += f'{manager.IndexToNode(index)} ({no_to_customer_id_dict[manager.IndexToNode(index)]})\n'
        plan_output += 'Distance of the route: {}km\n'.format(route_distance/1000)
        print(plan_output)
        max_route_distance = max(route_distance, max_route_distance)
        sum_distances += route_distance
    print('Maximum of the route distances: {}km'.format(max_route_distance/1000))
    print(f'Sum of the route distances: {sum_distances/1000}km')

# %%
def solve_distances(
    num_vehicles,
    vehicle_max_dist, # in km
    distance_global_span_cost_coefficient):
    
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model(num_vehicles)

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Add Distance constraint.
    dimension_name = 'Distance'
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        vehicle_max_dist*1000,  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name)
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(distance_global_span_cost_coefficient)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)
    else:
        print('No solution found !')

# %%
solve_distances(1,1000,100)
# Out:
# Objective: 28988919
# Route for vehicle 0:
#  0 (depot) ->  1 (9012) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  12 (9006) ->  13 (9019) ->  14 (9024) ->  6 (9010) ->  5 (9017) ->  7 (9025) ->  20 (9015) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) ->  21 (9008) ->  15 (9011) ->  10 (9007) ->  11 (9023) ->  8 (9018) ->  9 (9026) -> 0 (depot)
# Distance of the route: 287.019km
#
# Maximum of the route distances: 287.019km
# Sum of the route distances: 287.019km

# %%
solve_distances(2,1000,100)
# Out:
# Objective: 17284316
# Route for vehicle 0:
#  0 (depot) ->  1 (9012) ->  5 (9017) ->  7 (9025) ->  6 (9010) ->  14 (9024) ->  13 (9019) ->  12 (9006) -> 0 (depot)
# Distance of the route: 169.514km
#
# Route for vehicle 1:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  20 (9015) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) ->  21 (9008) ->  15 (9011) ->  10 (9007) ->  11 (9023) ->  8 (9018) ->  9 (9026) -> 0 (depot)
# Distance of the route: 163.402km
#
# Maximum of the route distances: 169.514km
# Sum of the route distances: 332.916km

# %%
solve_distances(3,1000,100)
# Out:
# Objective: 15689518
# Route for vehicle 0:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  5 (9017) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) ->  8 (9018) ->  9 (9026) -> 0 (depot)
# Distance of the route: 152.298km
#
# Route for vehicle 1:
#  0 (depot) ->  14 (9024) ->  13 (9019) ->  11 (9023) ->  10 (9007) ->  15 (9011) ->  21 (9008) -> 0 (depot)
# Distance of the route: 150.072km
#
# Route for vehicle 2:
#  0 (depot) ->  1 (9012) ->  20 (9015) ->  7 (9025) ->  6 (9010) ->  12 (9006) -> 0 (depot)
# Distance of the route: 152.348km
#
# Maximum of the route distances: 152.348km
# Sum of the route distances: 454.718km

# %%
solve_distances(4,1000,100)
# Out:
# Objective: 14328744
# Route for vehicle 0:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) -> 0 (depot)
# Distance of the route: 119.319km
#
# Route for vehicle 1:
#  0 (depot) ->  9 (9026) ->  8 (9018) ->  11 (9023) ->  10 (9007) ->  15 (9011) ->  21 (9008) -> 0 (depot)
# Distance of the route: 72.868km
#
# Route for vehicle 2:
#  0 (depot) ->  13 (9019) ->  14 (9024) ->  6 (9010) ->  12 (9006) -> 0 (depot)
# Distance of the route: 109.677km
#
# Route for vehicle 3:
#  0 (depot) ->  20 (9015) ->  7 (9025) ->  5 (9017) ->  1 (9012) -> 0 (depot)
# Distance of the route: 138.88km
#
# Maximum of the route distances: 138.88km
# Sum of the route distances: 440.744km

# %%
solve_distances(5,1000,100)
# Out:
# Objective: 14328744
# Route for vehicle 0:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) -> 0 (depot)
# Distance of the route: 119.319km
#
# Route for vehicle 1:
#  0 (depot) ->  9 (9026) ->  8 (9018) ->  11 (9023) ->  10 (9007) ->  15 (9011) ->  21 (9008) -> 0 (depot)
# Distance of the route: 72.868km
#
# Route for vehicle 2:
#  0 (depot) ->  13 (9019) ->  14 (9024) ->  6 (9010) ->  12 (9006) -> 0 (depot)
# Distance of the route: 109.677km
#
# Route for vehicle 3:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 4:
#  0 (depot) ->  20 (9015) ->  7 (9025) ->  5 (9017) ->  1 (9012) -> 0 (depot)
# Distance of the route: 138.88km
#
# Maximum of the route distances: 138.88km
# Sum of the route distances: 440.744km

# %%
solve_distances(6,1000,100)
# Out:
# Objective: 14328744
# Route for vehicle 0:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) -> 0 (depot)
# Distance of the route: 119.319km
#
# Route for vehicle 1:
#  0 (depot) ->  9 (9026) ->  8 (9018) ->  11 (9023) ->  10 (9007) ->  15 (9011) ->  21 (9008) -> 0 (depot)
# Distance of the route: 72.868km
#
# Route for vehicle 2:
#  0 (depot) ->  13 (9019) ->  14 (9024) ->  6 (9010) ->  12 (9006) -> 0 (depot)
# Distance of the route: 109.677km
#
# Route for vehicle 3:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 4:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 5:
#  0 (depot) ->  20 (9015) ->  7 (9025) ->  5 (9017) ->  1 (9012) -> 0 (depot)
# Distance of the route: 138.88km
#
# Maximum of the route distances: 138.88km
# Sum of the route distances: 440.744km

# %%
solve_distances(7,1000,100)
# Out:
# Objective: 14328744
# Route for vehicle 0:
#  0 (depot) ->  4 (9003) ->  2 (9005) ->  3 (9002) ->  19 (9031) ->  18 (9022) ->  17 (9009) ->  16 (9014) -> 0 (depot)
# Distance of the route: 119.319km
#
# Route for vehicle 1:
#  0 (depot) ->  9 (9026) ->  8 (9018) ->  11 (9023) ->  10 (9007) ->  15 (9011) ->  21 (9008) -> 0 (depot)
# Distance of the route: 72.868km
#
# Route for vehicle 2:
#  0 (depot) ->  13 (9019) ->  14 (9024) ->  6 (9010) ->  12 (9006) -> 0 (depot)
# Distance of the route: 109.677km
#
# Route for vehicle 3:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 4:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 5:
#  0 (depot) -> 0 (depot)
# Distance of the route: 0.0km
#
# Route for vehicle 6:
#  0 (depot) ->  20 (9015) ->  7 (9025) ->  5 (9017) ->  1 (9012) -> 0 (depot)
# Distance of the route: 138.88km
#
# Maximum of the route distances: 138.88km
# Sum of the route distances: 440.744km
